# %% [markdown]
# ### **Problem statement**

# %% [markdown]
# Does democracy cause economic growth?

# %% [markdown]
# **Libraries imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# Set dimensions for all the plots of seaborn
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# **Loading data**

# %%
democracy_data=pd.read_csv('Data/democracy-index-eiu.csv')
gdpPerCapita_data=pd.read_csv('Data/gdp-per-capita-worldbank.csv')

# %%
democracy=democracy_data.copy()
gdpPerCapita=gdpPerCapita_data.copy()

# %%
print("Shape of democracy dataframe:",democracy.shape)
democracy.head()
# Out:
# Shape of democracy dataframe: (2765, 4)
#         Entity Code  Year  Democracy score
# 0  Afghanistan  AFG  2006             3.06
# 1  Afghanistan  AFG  2008             3.02
# 2  Afghanistan  AFG  2010             2.48
# 3  Afghanistan  AFG  2011             2.48
# 4  Afghanistan  AFG  2012             2.48

# %%
print("Shape of gdpPerCapita dataframe:",gdpPerCapita.shape)
gdpPerCapita.head()
# Out:
# Shape of gdpPerCapita dataframe: (6562, 4)
#         Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 0  Afghanistan  AFG  2002                                          1280.4631
# 1  Afghanistan  AFG  2003                                          1292.3335
# 2  Afghanistan  AFG  2004                                          1260.0605
# 3  Afghanistan  AFG  2005                                          1352.3207
# 4  Afghanistan  AFG  2006                                          1366.9932

# %%
democracy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2765 entries, 0 to 2764
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Entity           2765 non-null   object
#  1   Code             2669 non-null   object
#  2   Year             2765 non-null   int64
#  3   Democracy score  2765 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 86.5+ KB

# %%
gdpPerCapita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6562 entries, 0 to 6561
# Data columns (total 4 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Entity                                               6562 non-null   object
#  1   Code                                                 6133 non-null   object
#  2   Year                                                 6562 non-null   int64
#  3   GDP per capita, PPP (constant 2017 international $)  6562 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 205.2+ KB

# %%
democracy.describe()
# Out:
#               Year  Democracy score
# count  2765.000000      2765.000000
# mean   2015.259675         5.500987
# std       4.897042         2.191708
# min    2006.000000         0.320000
# 25%    2011.000000         3.530000
# 50%    2015.000000         5.790000
# 75%    2019.000000         7.240000
# max    2023.000000         9.930000

# %%
gdpPerCapita.describe()
# Out:
#               Year  GDP per capita, PPP (constant 2017 international $)
# count  6562.000000                                        6562.000000
# mean   2006.434014                                       18307.128922
# std       9.415812                                       20344.959620
# min    1990.000000                                         430.413540
# 25%    1998.000000                                        3726.793100
# 50%    2007.000000                                       10638.246000
# 75%    2015.000000                                       26873.173500
# max    2022.000000                                      157600.640000

# %% [markdown]
# ##### **Data cleaning and preparation**

# %%
# Dropping columns that are not necessary
colsToBeDropped=['Code']
democracy=democracy.drop(columns=colsToBeDropped,axis=1)
gdpPerCapita=gdpPerCapita.drop(columns=colsToBeDropped,axis=1)

# %%
democracy.rename(columns={'Democracy score': 'democracy_score'}, inplace=True)
gdpPerCapita.rename(columns={'GDP per capita, PPP (constant 2017 international $)': 'gdpPerCapita'}, inplace=True)

# %%
democracy.head()
# Out:
#         Entity  Year  democracy_score
# 0  Afghanistan  2006             3.06
# 1  Afghanistan  2008             3.02
# 2  Afghanistan  2010             2.48
# 3  Afghanistan  2011             2.48
# 4  Afghanistan  2012             2.48

# %%
gdpPerCapita.head()
# Out:
#         Entity  Year  gdpPerCapita
# 0  Afghanistan  2002     1280.4631
# 1  Afghanistan  2003     1292.3335
# 2  Afghanistan  2004     1260.0605
# 3  Afghanistan  2005     1352.3207
# 4  Afghanistan  2006     1366.9932

# %%
democracy=democracy[(democracy.Year<2023)]
gdpPerCapita=gdpPerCapita[(gdpPerCapita.Year>=2006)]

# %%
def check_year_count(entity_name):
  democracy_count = democracy[democracy['Entity'] == entity_name]['Year'].count()
  gdpPerCapita_count = gdpPerCapita[gdpPerCapita['Entity'] == entity_name]['Year'].count()
  
  print(f"Year count for {entity_name} in democracy dataframe: {democracy_count}")
  print(f"Year count for {entity_name} in gdpPerCapita dataframe: {gdpPerCapita_count}")
  
  return democracy_count,gdpPerCapita_count

check_year_count('Afghanistan')
# Out:
# Year count for Afghanistan in democracy dataframe: 15
# Year count for Afghanistan in gdpPerCapita dataframe: 16
# (np.int64(15), np.int64(16))

# %%
def find_missing_years(entity_name):
  democracy_count, gdpPerCapita_count = check_year_count(entity_name)
  
  if democracy_count != gdpPerCapita_count:
    democracy_years = set(democracy[(democracy['Entity'] == entity_name) & (democracy['Year'] >= 2006) & (democracy['Year'] <= 2022)]['Year'])
    gdpPerCapita_years = set(gdpPerCapita[(gdpPerCapita['Entity'] == entity_name) & (gdpPerCapita['Year'] >= 2006) & (gdpPerCapita['Year'] <= 2022)]['Year'])
    
    missing_in_democracy = sorted(gdpPerCapita_years - democracy_years)
    missing_in_gdpPerCapita = sorted(democracy_years - gdpPerCapita_years)
    
    if missing_in_democracy:
      print(f"Years missing in democracy dataframe for {entity_name}: {missing_in_democracy}")
    if missing_in_gdpPerCapita:
      print(f"Years missing in gdpPerCapita dataframe for {entity_name}: {missing_in_gdpPerCapita}")
  else:
    print(f"No missing years for {entity_name} between 2006 and 2022.")

  return missing_in_democracy,missing_in_gdpPerCapita

find_missing_years('Afghanistan')
# Out:
# Year count for Afghanistan in democracy dataframe: 15
# Year count for Afghanistan in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for Afghanistan: [2007, 2009]
# Years missing in gdpPerCapita dataframe for Afghanistan: [2022]
# ([2007, 2009], [2022])

# %%
def get_missing_years_dataframe():
  entities = set(democracy['Entity']).union(set(gdpPerCapita['Entity']))
  missing_years_data = []

  for entity in entities:
    missing_in_democracy, missing_in_gdpPerCapita = find_missing_years(entity)
    missing_years_data.append({
      'Country': entity,
      'Missing in Democracy': missing_in_democracy,
      'Missing in GDP per Capita': missing_in_gdpPerCapita
    })

  missing_years_df = pd.DataFrame(missing_years_data)
  return missing_years_df

missing_years_df = get_missing_years_dataframe()
missing_years_df
# Out:
# Year count for South Korea in democracy dataframe: 15
# Year count for South Korea in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for South Korea: [2007, 2009]
# Year count for Lower-middle-income countries in democracy dataframe: 0
# Year count for Lower-middle-income countries in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Lower-middle-income countries: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Mexico in democracy dataframe: 15
# Year count for Mexico in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Mexico: [2007, 2009]
# Year count for Grenada in democracy dataframe: 0
# Year count for Grenada in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Grenada: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Brunei in democracy dataframe: 0
# Year count for Brunei in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Brunei: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Burkina Faso in democracy dataframe: 15
# Year count for Burkina Faso in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Burkina Faso: [2007, 2009]
# Year count for Dominica in democracy dataframe: 0
# Year count for Dominica in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Dominica: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Iran in democracy dataframe: 15
# Year count for Iran in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Iran: [2007, 2009]
# Year count for Bosnia and Herzegovina in democracy dataframe: 15
# Year count for Bosnia and Herzegovina in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bosnia and Herzegovina: [2007, 2009]
# Year count for Estonia in democracy dataframe: 15
# Year count for Estonia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Estonia: [2007, 2009]
# Year count for Qatar in democracy dataframe: 15
# Year count for Qatar in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Qatar: [2007, 2009]
# Year count for Tuvalu in democracy dataframe: 0
# Year count for Tuvalu in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Tuvalu: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Africa in democracy dataframe: 15
# Year count for Africa in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Africa: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for United States in democracy dataframe: 15
# Year count for United States in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for United States: [2007, 2009]
# Year count for World in democracy dataframe: 15
# Year count for World in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for World: [2007, 2009]
# Year count for Middle-income countries in democracy dataframe: 0
# Year count for Middle-income countries in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Middle-income countries: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Bulgaria in democracy dataframe: 15
# Year count for Bulgaria in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bulgaria: [2007, 2009]
# Year count for Samoa in democracy dataframe: 0
# Year count for Samoa in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Samoa: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Morocco in democracy dataframe: 15
# Year count for Morocco in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Morocco: [2007, 2009]
# Year count for North America (WB) in democracy dataframe: 0
# Year count for North America (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for North America (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Brazil in democracy dataframe: 15
# Year count for Brazil in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Brazil: [2007, 2009]
# Year count for Saint Vincent and the Grenadines in democracy dataframe: 0
# Year count for Saint Vincent and the Grenadines in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Saint Vincent and the Grenadines: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Moldova in democracy dataframe: 15
# Year count for Moldova in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Moldova: [2007, 2009]
# Year count for Madagascar in democracy dataframe: 15
# Year count for Madagascar in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Madagascar: [2007, 2009]
# Year count for Japan in democracy dataframe: 15
# Year count for Japan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Japan: [2007, 2009]
# Year count for Guinea-Bissau in democracy dataframe: 15
# Year count for Guinea-Bissau in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Guinea-Bissau: [2007, 2009]
# Year count for Belize in democracy dataframe: 0
# Year count for Belize in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Belize: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Guyana in democracy dataframe: 15
# Year count for Guyana in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Guyana: [2007, 2009]
# Year count for Montenegro in democracy dataframe: 15
# Year count for Montenegro in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Montenegro: [2007, 2009]
# Year count for Sweden in democracy dataframe: 15
# Year count for Sweden in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Sweden: [2007, 2009]
# Year count for Peru in democracy dataframe: 15
# Year count for Peru in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Peru: [2007, 2009]
# Year count for Marshall Islands in democracy dataframe: 0
# Year count for Marshall Islands in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Marshall Islands: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Upper-middle-income countries in democracy dataframe: 0
# Year count for Upper-middle-income countries in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Upper-middle-income countries: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Bahrain in democracy dataframe: 15
# Year count for Bahrain in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bahrain: [2007, 2009]
# Year count for Canada in democracy dataframe: 15
# Year count for Canada in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Canada: [2007, 2009]
# Year count for Gabon in democracy dataframe: 15
# Year count for Gabon in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Gabon: [2007, 2009]
# Year count for North America in democracy dataframe: 15
# Year count for North America in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for North America: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Pakistan in democracy dataframe: 15
# Year count for Pakistan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Pakistan: [2007, 2009]
# Year count for El Salvador in democracy dataframe: 15
# Year count for El Salvador in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for El Salvador: [2007, 2009]
# Year count for Bhutan in democracy dataframe: 15
# Year count for Bhutan in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for Bhutan: [2007, 2009]
# Years missing in gdpPerCapita dataframe for Bhutan: [2022]
# Year count for Armenia in democracy dataframe: 15
# Year count for Armenia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Armenia: [2007, 2009]
# Year count for Serbia in democracy dataframe: 15
# Year count for Serbia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Serbia: [2007, 2009]
# Year count for Greece in democracy dataframe: 15
# Year count for Greece in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Greece: [2007, 2009]
# Year count for Papua New Guinea in democracy dataframe: 15
# Year count for Papua New Guinea in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Papua New Guinea: [2007, 2009]
# Year count for Iraq in democracy dataframe: 15
# Year count for Iraq in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Iraq: [2007, 2009]
# Year count for Hong Kong in democracy dataframe: 15
# Year count for Hong Kong in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Hong Kong: [2007, 2009]
# Year count for Cyprus in democracy dataframe: 15
# Year count for Cyprus in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Cyprus: [2007, 2009]
# Year count for Dominican Republic in democracy dataframe: 15
# Year count for Dominican Republic in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Dominican Republic: [2007, 2009]
# Year count for Bahamas in democracy dataframe: 0
# Year count for Bahamas in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bahamas: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Costa Rica in democracy dataframe: 15
# Year count for Costa Rica in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Costa Rica: [2007, 2009]
# Year count for Georgia in democracy dataframe: 15
# Year count for Georgia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Georgia: [2007, 2009]
# Year count for Aruba in democracy dataframe: 0
# Year count for Aruba in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Aruba: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Panama in democracy dataframe: 15
# Year count for Panama in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Panama: [2007, 2009]
# Year count for Saint Kitts and Nevis in democracy dataframe: 0
# Year count for Saint Kitts and Nevis in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Saint Kitts and Nevis: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Sao Tome and Principe in democracy dataframe: 0
# Year count for Sao Tome and Principe in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Sao Tome and Principe: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Cape Verde in democracy dataframe: 15
# Year count for Cape Verde in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Cape Verde: [2007, 2009]
# Year count for East Asia and Pacific (WB) in democracy dataframe: 0
# Year count for East Asia and Pacific (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for East Asia and Pacific (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Nigeria in democracy dataframe: 15
# Year count for Nigeria in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Nigeria: [2007, 2009]
# Year count for South Africa in democracy dataframe: 15
# Year count for South Africa in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for South Africa: [2007, 2009]
# Year count for Somalia in democracy dataframe: 0
# Year count for Somalia in gdpPerCapita dataframe: 10
# Years missing in democracy dataframe for Somalia: [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Liberia in democracy dataframe: 15
# Year count for Liberia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Liberia: [2007, 2009]
# Year count for Cambodia in democracy dataframe: 15
# Year count for Cambodia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Cambodia: [2007, 2009]
# Year count for Oman in democracy dataframe: 15
# Year count for Oman in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Oman: [2007, 2009]
# Year count for Denmark in democracy dataframe: 15
# Year count for Denmark in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Denmark: [2007, 2009]
# Year count for Sint Maarten (Dutch part) in democracy dataframe: 0
# Year count for Sint Maarten (Dutch part) in gdpPerCapita dataframe: 14
# Years missing in democracy dataframe for Sint Maarten (Dutch part): [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Cameroon in democracy dataframe: 15
# Year count for Cameroon in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Cameroon: [2007, 2009]
# Year count for Europe and Central Asia (WB) in democracy dataframe: 0
# Year count for Europe and Central Asia (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Europe and Central Asia (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Portugal in democracy dataframe: 15
# Year count for Portugal in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Portugal: [2007, 2009]
# Year count for Cuba in democracy dataframe: 15
# Year count for Cuba in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Cuba: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for New Zealand in democracy dataframe: 15
# Year count for New Zealand in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for New Zealand: [2007, 2009]
# Year count for Lithuania in democracy dataframe: 15
# Year count for Lithuania in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Lithuania: [2007, 2009]
# Year count for Latvia in democracy dataframe: 15
# Year count for Latvia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Latvia: [2007, 2009]
# Year count for Netherlands in democracy dataframe: 15
# Year count for Netherlands in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Netherlands: [2007, 2009]
# Year count for Croatia in democracy dataframe: 15
# Year count for Croatia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Croatia: [2007, 2009]
# Year count for Austria in democracy dataframe: 15
# Year count for Austria in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Austria: [2007, 2009]
# Year count for Low-income countries in democracy dataframe: 0
# Year count for Low-income countries in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Low-income countries: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Norway in democracy dataframe: 15
# Year count for Norway in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Norway: [2007, 2009]
# Year count for United Kingdom in democracy dataframe: 15
# Year count for United Kingdom in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for United Kingdom: [2007, 2009]
# Year count for Paraguay in democracy dataframe: 15
# Year count for Paraguay in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Paraguay: [2007, 2009]
# Year count for Burundi in democracy dataframe: 15
# Year count for Burundi in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Burundi: [2007, 2009]
# Year count for Turkmenistan in democracy dataframe: 15
# Year count for Turkmenistan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Turkmenistan: [2007, 2009]
# Year count for Vietnam in democracy dataframe: 15
# Year count for Vietnam in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Vietnam: [2007, 2009]
# Year count for Central African Republic in democracy dataframe: 15
# Year count for Central African Republic in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Central African Republic: [2007, 2009]
# Year count for Sri Lanka in democracy dataframe: 15
# Year count for Sri Lanka in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Sri Lanka: [2007, 2009]
# Year count for Libya in democracy dataframe: 15
# Year count for Libya in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Libya: [2007, 2009]
# Year count for Afghanistan in democracy dataframe: 15
# Year count for Afghanistan in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for Afghanistan: [2007, 2009]
# Years missing in gdpPerCapita dataframe for Afghanistan: [2022]
# Year count for Congo in democracy dataframe: 15
# Year count for Congo in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Congo: [2007, 2009]
# Year count for Mongolia in democracy dataframe: 15
# Year count for Mongolia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Mongolia: [2007, 2009]
# Year count for Belarus in democracy dataframe: 15
# Year count for Belarus in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Belarus: [2007, 2009]
# Year count for Uganda in democracy dataframe: 15
# Year count for Uganda in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Uganda: [2007, 2009]
# Year count for Democratic Republic of Congo in democracy dataframe: 15
# Year count for Democratic Republic of Congo in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Democratic Republic of Congo: [2007, 2009]
# Year count for Italy in democracy dataframe: 15
# Year count for Italy in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Italy: [2007, 2009]
# Year count for Europe in democracy dataframe: 15
# Year count for Europe in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Europe: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Cayman Islands in democracy dataframe: 0
# Year count for Cayman Islands in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Cayman Islands: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for India in democracy dataframe: 15
# Year count for India in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for India: [2007, 2009]
# Year count for Luxembourg in democracy dataframe: 15
# Year count for Luxembourg in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Luxembourg: [2007, 2009]
# Year count for Maldives in democracy dataframe: 0
# Year count for Maldives in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Maldives: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Asia in democracy dataframe: 15
# Year count for Asia in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Asia: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Bolivia in democracy dataframe: 15
# Year count for Bolivia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bolivia: [2007, 2009]
# Year count for Guinea in democracy dataframe: 15
# Year count for Guinea in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Guinea: [2007, 2009]
# Year count for Niger in democracy dataframe: 15
# Year count for Niger in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Niger: [2007, 2009]
# Year count for Mozambique in democracy dataframe: 15
# Year count for Mozambique in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Mozambique: [2007, 2009]
# Year count for South Asia (WB) in democracy dataframe: 0
# Year count for South Asia (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for South Asia (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Iceland in democracy dataframe: 15
# Year count for Iceland in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Iceland: [2007, 2009]
# Year count for Finland in democracy dataframe: 15
# Year count for Finland in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Finland: [2007, 2009]
# Year count for Syria in democracy dataframe: 15
# Year count for Syria in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Syria: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Switzerland in democracy dataframe: 15
# Year count for Switzerland in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Switzerland: [2007, 2009]
# Year count for Ireland in democracy dataframe: 15
# Year count for Ireland in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Ireland: [2007, 2009]
# Year count for Equatorial Guinea in democracy dataframe: 15
# Year count for Equatorial Guinea in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Equatorial Guinea: [2007, 2009]
# Year count for Comoros in democracy dataframe: 15
# Year count for Comoros in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Comoros: [2007, 2009]
# Year count for Latin America and Caribbean (WB) in democracy dataframe: 0
# Year count for Latin America and Caribbean (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Latin America and Caribbean (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Curacao in democracy dataframe: 0
# Year count for Curacao in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Curacao: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Tajikistan in democracy dataframe: 15
# Year count for Tajikistan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Tajikistan: [2007, 2009]
# Year count for Bermuda in democracy dataframe: 0
# Year count for Bermuda in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bermuda: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for East Timor in democracy dataframe: 15
# Year count for East Timor in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for East Timor: [2007, 2009]
# Year count for Cote d'Ivoire in democracy dataframe: 15
# Year count for Cote d'Ivoire in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Cote d'Ivoire: [2007, 2009]
# Year count for Puerto Rico in democracy dataframe: 0
# Year count for Puerto Rico in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Puerto Rico: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Benin in democracy dataframe: 15
# Year count for Benin in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Benin: [2007, 2009]
# Year count for Namibia in democracy dataframe: 15
# Year count for Namibia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Namibia: [2007, 2009]
# Year count for Seychelles in democracy dataframe: 0
# Year count for Seychelles in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Seychelles: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Indonesia in democracy dataframe: 15
# Year count for Indonesia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Indonesia: [2007, 2009]
# Year count for Turks and Caicos Islands in democracy dataframe: 0
# Year count for Turks and Caicos Islands in gdpPerCapita dataframe: 12
# Years missing in democracy dataframe for Turks and Caicos Islands: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Eritrea in democracy dataframe: 15
# Year count for Eritrea in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Eritrea: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Colombia in democracy dataframe: 15
# Year count for Colombia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Colombia: [2007, 2009]
# Year count for Yemen in democracy dataframe: 15
# Year count for Yemen in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Yemen: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Malawi in democracy dataframe: 15
# Year count for Malawi in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Malawi: [2007, 2009]
# Year count for Algeria in democracy dataframe: 15
# Year count for Algeria in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Algeria: [2007, 2009]
# Year count for Bangladesh in democracy dataframe: 15
# Year count for Bangladesh in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Bangladesh: [2007, 2009]
# Year count for Uruguay in democracy dataframe: 15
# Year count for Uruguay in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Uruguay: [2007, 2009]
# Year count for United Arab Emirates in democracy dataframe: 15
# Year count for United Arab Emirates in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for United Arab Emirates: [2007, 2009]
# Year count for Mauritius in democracy dataframe: 15
# Year count for Mauritius in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Mauritius: [2007, 2009]
# Year count for Hungary in democracy dataframe: 15
# Year count for Hungary in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Hungary: [2007, 2009]
# Year count for Palau in democracy dataframe: 0
# Year count for Palau in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for Palau: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Year count for Vanuatu in democracy dataframe: 0
# Year count for Vanuatu in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Vanuatu: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for North Macedonia in democracy dataframe: 15
# Year count for North Macedonia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for North Macedonia: [2007, 2009]
# Year count for Laos in democracy dataframe: 15
# Year count for Laos in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Laos: [2007, 2009]
# Year count for Oceania in democracy dataframe: 15
# Year count for Oceania in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Oceania: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Myanmar in democracy dataframe: 15
# Year count for Myanmar in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Myanmar: [2007, 2009]
# Year count for Malaysia in democracy dataframe: 15
# Year count for Malaysia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Malaysia: [2007, 2009]
# Year count for Nauru in democracy dataframe: 0
# Year count for Nauru in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Nauru: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Haiti in democracy dataframe: 15
# Year count for Haiti in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Haiti: [2007, 2009]
# Year count for Suriname in democracy dataframe: 15
# Year count for Suriname in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Suriname: [2007, 2009]
# Year count for Australia in democracy dataframe: 15
# Year count for Australia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Australia: [2007, 2009]
# Year count for Honduras in democracy dataframe: 15
# Year count for Honduras in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Honduras: [2007, 2009]
# Year count for Kenya in democracy dataframe: 15
# Year count for Kenya in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Kenya: [2007, 2009]
# Year count for Chad in democracy dataframe: 15
# Year count for Chad in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Chad: [2007, 2009]
# Year count for Slovakia in democracy dataframe: 15
# Year count for Slovakia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Slovakia: [2007, 2009]
# Year count for Middle East and North Africa (WB) in democracy dataframe: 0
# Year count for Middle East and North Africa (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Middle East and North Africa (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Kazakhstan in democracy dataframe: 15
# Year count for Kazakhstan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Kazakhstan: [2007, 2009]
# Year count for Angola in democracy dataframe: 15
# Year count for Angola in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Angola: [2007, 2009]
# Year count for Singapore in democracy dataframe: 15
# Year count for Singapore in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Singapore: [2007, 2009]
# Year count for Malta in democracy dataframe: 15
# Year count for Malta in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Malta: [2007, 2009]
# Year count for Venezuela in democracy dataframe: 15
# Year count for Venezuela in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Venezuela: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Sierra Leone in democracy dataframe: 15
# Year count for Sierra Leone in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Sierra Leone: [2007, 2009]
# Year count for European Union (27) in democracy dataframe: 0
# Year count for European Union (27) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for European Union (27): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Belgium in democracy dataframe: 15
# Year count for Belgium in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Belgium: [2007, 2009]
# Year count for Slovenia in democracy dataframe: 15
# Year count for Slovenia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Slovenia: [2007, 2009]
# Year count for Kyrgyzstan in democracy dataframe: 15
# Year count for Kyrgyzstan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Kyrgyzstan: [2007, 2009]
# Year count for China in democracy dataframe: 15
# Year count for China in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for China: [2007, 2009]
# Year count for Kuwait in democracy dataframe: 15
# Year count for Kuwait in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Kuwait: [2007, 2009]
# Year count for Jamaica in democracy dataframe: 15
# Year count for Jamaica in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Jamaica: [2007, 2009]
# Year count for Albania in democracy dataframe: 15
# Year count for Albania in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Albania: [2007, 2009]
# Year count for Barbados in democracy dataframe: 0
# Year count for Barbados in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Barbados: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Fiji in democracy dataframe: 15
# Year count for Fiji in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Fiji: [2007, 2009]
# Year count for Guatemala in democracy dataframe: 15
# Year count for Guatemala in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Guatemala: [2007, 2009]
# Year count for Israel in democracy dataframe: 15
# Year count for Israel in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Israel: [2007, 2009]
# Year count for Eswatini in democracy dataframe: 15
# Year count for Eswatini in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Eswatini: [2007, 2009]
# Year count for Botswana in democracy dataframe: 15
# Year count for Botswana in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Botswana: [2007, 2009]
# Year count for San Marino in democracy dataframe: 0
# Year count for San Marino in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for San Marino: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Year count for France in democracy dataframe: 15
# Year count for France in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for France: [2007, 2009]
# Year count for Saudi Arabia in democracy dataframe: 15
# Year count for Saudi Arabia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Saudi Arabia: [2007, 2009]
# Year count for Antigua and Barbuda in democracy dataframe: 0
# Year count for Antigua and Barbuda in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Antigua and Barbuda: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Chile in democracy dataframe: 15
# Year count for Chile in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Chile: [2007, 2009]
# Year count for Poland in democracy dataframe: 15
# Year count for Poland in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Poland: [2007, 2009]
# Year count for Ecuador in democracy dataframe: 15
# Year count for Ecuador in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Ecuador: [2007, 2009]
# Year count for Nepal in democracy dataframe: 15
# Year count for Nepal in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Nepal: [2007, 2009]
# Year count for Ghana in democracy dataframe: 15
# Year count for Ghana in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Ghana: [2007, 2009]
# Year count for Nicaragua in democracy dataframe: 15
# Year count for Nicaragua in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Nicaragua: [2007, 2009]
# Year count for Zambia in democracy dataframe: 15
# Year count for Zambia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Zambia: [2007, 2009]
# Year count for Kosovo in democracy dataframe: 0
# Year count for Kosovo in gdpPerCapita dataframe: 15
# Years missing in democracy dataframe for Kosovo: [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Argentina in democracy dataframe: 15
# Year count for Argentina in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Argentina: [2007, 2009]
# Year count for Philippines in democracy dataframe: 15
# Year count for Philippines in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Philippines: [2007, 2009]
# Year count for Mali in democracy dataframe: 15
# Year count for Mali in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Mali: [2007, 2009]
# Year count for Lebanon in democracy dataframe: 15
# Year count for Lebanon in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for Lebanon: [2007, 2009]
# Years missing in gdpPerCapita dataframe for Lebanon: [2022]
# Year count for Taiwan in democracy dataframe: 15
# Year count for Taiwan in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for Taiwan: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for South America in democracy dataframe: 15
# Year count for South America in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for South America: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Kiribati in democracy dataframe: 0
# Year count for Kiribati in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Kiribati: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Romania in democracy dataframe: 15
# Year count for Romania in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Romania: [2007, 2009]
# Year count for Ethiopia in democracy dataframe: 15
# Year count for Ethiopia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Ethiopia: [2007, 2009]
# Year count for Egypt in democracy dataframe: 15
# Year count for Egypt in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Egypt: [2007, 2009]
# Year count for Senegal in democracy dataframe: 15
# Year count for Senegal in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Senegal: [2007, 2009]
# Year count for Spain in democracy dataframe: 15
# Year count for Spain in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Spain: [2007, 2009]
# Year count for Rwanda in democracy dataframe: 15
# Year count for Rwanda in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Rwanda: [2007, 2009]
# Year count for Tunisia in democracy dataframe: 15
# Year count for Tunisia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Tunisia: [2007, 2009]
# Year count for Lesotho in democracy dataframe: 15
# Year count for Lesotho in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Lesotho: [2007, 2009]
# Year count for Jordan in democracy dataframe: 15
# Year count for Jordan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Jordan: [2007, 2009]
# Year count for Germany in democracy dataframe: 15
# Year count for Germany in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Germany: [2007, 2009]
# Year count for Ukraine in democracy dataframe: 15
# Year count for Ukraine in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Ukraine: [2007, 2009]
# Year count for Turkey in democracy dataframe: 15
# Year count for Turkey in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Turkey: [2007, 2009]
# Year count for North Korea in democracy dataframe: 15
# Year count for North Korea in gdpPerCapita dataframe: 0
# Years missing in gdpPerCapita dataframe for North Korea: [2006, 2008, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Azerbaijan in democracy dataframe: 15
# Year count for Azerbaijan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Azerbaijan: [2007, 2009]
# Year count for High-income countries in democracy dataframe: 0
# Year count for High-income countries in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for High-income countries: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Tonga in democracy dataframe: 0
# Year count for Tonga in gdpPerCapita dataframe: 16
# Years missing in democracy dataframe for Tonga: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Year count for Gambia in democracy dataframe: 15
# Year count for Gambia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Gambia: [2007, 2009]
# Year count for Uzbekistan in democracy dataframe: 15
# Year count for Uzbekistan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Uzbekistan: [2007, 2009]
# Year count for Tanzania in democracy dataframe: 15
# Year count for Tanzania in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Tanzania: [2007, 2009]
# Year count for Djibouti in democracy dataframe: 15
# Year count for Djibouti in gdpPerCapita dataframe: 10
# Years missing in gdpPerCapita dataframe for Djibouti: [2006, 2008, 2010, 2011, 2012]
# Year count for Mauritania in democracy dataframe: 15
# Year count for Mauritania in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Mauritania: [2007, 2009]
# Year count for Palestine in democracy dataframe: 15
# Year count for Palestine in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Palestine: [2007, 2009]
# Year count for Saint Lucia in democracy dataframe: 0
# Year count for Saint Lucia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Saint Lucia: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Sub-Saharan Africa (WB) in democracy dataframe: 0
# Year count for Sub-Saharan Africa (WB) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Sub-Saharan Africa (WB): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Sudan in democracy dataframe: 15
# Year count for Sudan in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Sudan: [2007, 2009]
# Year count for Solomon Islands in democracy dataframe: 0
# Year count for Solomon Islands in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Solomon Islands: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Togo in democracy dataframe: 15
# Year count for Togo in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Togo: [2007, 2009]
# Year count for Zimbabwe in democracy dataframe: 15
# Year count for Zimbabwe in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Zimbabwe: [2007, 2009]
# Year count for Thailand in democracy dataframe: 15
# Year count for Thailand in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Thailand: [2007, 2009]
# Year count for Russia in democracy dataframe: 15
# Year count for Russia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Russia: [2007, 2009]
# Year count for Trinidad and Tobago in democracy dataframe: 15
# Year count for Trinidad and Tobago in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Trinidad and Tobago: [2007, 2009]
# Year count for Czechia in democracy dataframe: 15
# Year count for Czechia in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Czechia: [2007, 2009]
# Year count for Macao in democracy dataframe: 0
# Year count for Macao in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Macao: [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Year count for Micronesia (country) in democracy dataframe: 0
# Year count for Micronesia (country) in gdpPerCapita dataframe: 17
# Years missing in democracy dataframe for Micronesia (country): [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
#                            Country  \
# 0                      South Korea
# 1    Lower-middle-income countries
# 2                           Mexico
# 3                          Grenada
# 4                           Brunei
# ..                             ...
# 216                         Russia
# 217            Trinidad and Tobago
# 218                        Czechia
# 219                          Macao
# 220           Micronesia (country)
#
#                                   Missing in Democracy  \
# 0                                         [2007, 2009]
# 1    [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 2                                         [2007, 2009]
# 3    [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 4    [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# ..                                                 ...
# 216                                       [2007, 2009]
# 217                                       [2007, 2009]
# 218                                       [2007, 2009]
# 219  [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 220  [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
#
#     Missing in GDP per Capita
# 0                          []
# 1                          []
# 2                          []
# 3                          []
# 4                          []
# ..                        ...
# 216                        []
# 217                        []
# 218                        []
# 219                        []
# 220                        []
#
# [221 rows x 3 columns]

# %%
# Get the list of countries that are missing more than two years in democracy dataframe
countries_to_remove = missing_years_df[missing_years_df['Missing in Democracy'].apply(len) > 2]['Country'].tolist()
print(countries_to_remove)
# Remove these countries from the democracy dataframe
democracy = democracy[~democracy['Entity'].isin(countries_to_remove)]
democracy.head()
# Out:
# ['Lower-middle-income countries', 'Grenada', 'Brunei', 'Dominica', 'Tuvalu', 'Middle-income countries', 'Samoa', 'North America (WB)', 'Saint Vincent and the Grenadines', 'Belize', 'Marshall Islands', 'Upper-middle-income countries', 'Bahamas', 'Aruba', 'Saint Kitts and Nevis', 'Sao Tome and Principe', 'East Asia and Pacific (WB)', 'Somalia', 'Sint Maarten (Dutch part)', 'Europe and Central Asia (WB)', 'Low-income countries', 'Cayman Islands', 'Maldives', 'South Asia (WB)', 'Latin America and Caribbean (WB)', 'Curacao', 'Bermuda', 'Puerto Rico', 'Seychelles', 'Turks and Caicos Islands', 'Palau', 'Vanuatu', 'Nauru', 'Middle East and North Africa (WB)', 'European Union (27)', 'Barbados', 'San Marino', 'Antigua and Barbuda', 'Kosovo', 'Kiribati', 'High-income countries', 'Tonga', 'Saint Lucia', 'Sub-Saharan Africa (WB)', 'Solomon Islands', 'Macao', 'Micronesia (country)']
#         Entity  Year  democracy_score
# 0  Afghanistan  2006             3.06
# 1  Afghanistan  2008             3.02
# 2  Afghanistan  2010             2.48
# 3  Afghanistan  2011             2.48
# 4  Afghanistan  2012             2.48

# %%
# Remove the countries from the gdpPerCapita dataframe
gdpPerCapita = gdpPerCapita[~gdpPerCapita['Entity'].isin(countries_to_remove)]
# Display the unique number of Entity in each dataframe
unique_entities_democracy = democracy['Entity'].nunique()
unique_entities_gdpPerCapita = gdpPerCapita['Entity'].nunique()

print(f"Unique number of Entity in democracy dataframe: {unique_entities_democracy}")
print(f"Unique number of Entity in gdpPerCapita dataframe: {unique_entities_gdpPerCapita}")
# Out:
# Unique number of Entity in democracy dataframe: 174
# Unique number of Entity in gdpPerCapita dataframe: 161

# %%
# Get the list of entities present in the gdpPerCapita dataframe
entities_in_gdpPerCapita = set(gdpPerCapita['Entity'])
# Remove entities from the democracy dataframe that are not in the gdpPerCapita dataframe
democracy = democracy[democracy['Entity'].isin(entities_in_gdpPerCapita)]
unique_entities_democracy = democracy['Entity'].nunique()
print(f"Unique number of Entity in democracy dataframe: {unique_entities_democracy}")
print(f"Unique number of Entity in gdpPerCapita dataframe: {unique_entities_gdpPerCapita}")
# Out:
# Unique number of Entity in democracy dataframe: 161
# Unique number of Entity in gdpPerCapita dataframe: 161

# %%
# Merge the two dataframes on the 'Entity' and 'Year' columns
merged_df = pd.merge(democracy, gdpPerCapita, on=['Entity', 'Year'])
# Print the dimensions of the new dataframe
print("Dimensions of the merged dataframe:", merged_df.shape)
# Out:
# Dimensions of the merged dataframe: (2407, 4)

# %%
merged_df.head()
# Out:
#         Entity  Year  democracy_score  gdpPerCapita
# 0  Afghanistan  2006             3.06     1366.9932
# 1  Afghanistan  2008             3.02     1556.8445
# 2  Afghanistan  2010             2.48     2026.1638
# 3  Afghanistan  2011             2.48     1961.0963
# 4  Afghanistan  2012             2.48     2122.8308

# %% [markdown]
# I have decided to fill the missing values for democracy index and GDP by taking the mean of the previous and the following value.

# %%
def fill_missing_years(df, entity, year_col, value_cols):
    for year in range(2006, 2023):
        if year not in df[df['Entity'] == entity][year_col].values:
            prev_year = year - 1
            next_year = year + 1
            
            if prev_year in df[df['Entity'] == entity][year_col].values and next_year in df[df['Entity'] == entity][year_col].values:
                prev_values = df[(df['Entity'] == entity) & (df[year_col] == prev_year)][value_cols].values[0]
                next_values = df[(df['Entity'] == entity) & (df[year_col] == next_year)][value_cols].values[0]
                
                mean_values = (prev_values + next_values) / 2
                new_row = {'Entity': entity, year_col: year}
                new_row.update(dict(zip(value_cols, mean_values)))
                
                new_row_df = pd.DataFrame([new_row])  
                df = pd.concat([df, new_row_df], ignore_index=True)  
    return df

# Apply the function to fill missing years for each country
for entity in merged_df['Entity'].unique():
    merged_df = fill_missing_years(merged_df, entity, 'Year', ['democracy_score', 'gdpPerCapita'])

# Sort the dataframe by Entity and Year
merged_df = merged_df.sort_values(by=['Entity', 'Year']).reset_index(drop=True)

merged_df.head(20)  # Display the first 20 rows to verify the changes
# Out:
#          Entity  Year  democracy_score  gdpPerCapita
# 0   Afghanistan  2006            3.060    1366.99320
# 1   Afghanistan  2007            3.040    1461.91885
# 2   Afghanistan  2008            3.020    1556.84450
# 3   Afghanistan  2009            2.750    1791.50415
# 4   Afghanistan  2010            2.480    2026.16380
# 5   Afghanistan  2011            2.480    1961.09630
# 6   Afghanistan  2012            2.480    2122.83080
# 7   Afghanistan  2013            2.480    2165.34080
# 8   Afghanistan  2014            2.770    2144.44970
# 9   Afghanistan  2015            2.770    2108.71400
# 10  Afghanistan  2016            2.550    2101.42200
# 11  Afghanistan  2017            2.550    2096.09300
# 12  Afghanistan  2018            2.970    2060.69900
# 13  Afghanistan  2019            2.850    2079.92190
# 14  Afghanistan  2020            2.850    1968.34100
# 15  Afghanistan  2021            0.320    1516.27330
# 16      Albania  2006            5.910    8568.59200
# 17      Albania  2007            5.910    9240.39450
# 18      Albania  2008            5.910    9912.19700
# 19      Albania  2009            5.885   10330.85800

# %%
# Calculate the percentage change in GDP per capita for each country over time
merged_df['gdpPerCapita_pct_change'] = merged_df.groupby('Entity')['gdpPerCapita'].pct_change() * 100
# Explicitly assign the result of fillna() to the column
merged_df['gdpPerCapita_pct_change'] = merged_df['gdpPerCapita_pct_change'].fillna(0)
merged_df.head(20)
# Out:
#          Entity  Year  democracy_score  gdpPerCapita  gdpPerCapita_pct_change
# 0   Afghanistan  2006            3.060    1366.99320                 0.000000
# 1   Afghanistan  2007            3.040    1461.91885                 6.944120
# 2   Afghanistan  2008            3.020    1556.84450                 6.493223
# 3   Afghanistan  2009            2.750    1791.50415                15.072774
# 4   Afghanistan  2010            2.480    2026.16380                13.098471
# 5   Afghanistan  2011            2.480    1961.09630                -3.211364
# 6   Afghanistan  2012            2.480    2122.83080                 8.247147
# 7   Afghanistan  2013            2.480    2165.34080                 2.002515
# 8   Afghanistan  2014            2.770    2144.44970                -0.964795
# 9   Afghanistan  2015            2.770    2108.71400                -1.666428
# 10  Afghanistan  2016            2.550    2101.42200                -0.345803
# 11  Afghanistan  2017            2.550    2096.09300                -0.253590
# 12  Afghanistan  2018            2.970    2060.69900                -1.688570
# 13  Afghanistan  2019            2.850    2079.92190                 0.932834
# 14  Afghanistan  2020            2.850    1968.34100                -5.364668
# 15  Afghanistan  2021            0.320    1516.27330               -22.966940
# 16      Albania  2006            5.910    8568.59200                 0.000000
# 17      Albania  2007            5.910    9240.39450                 7.840290
# 18      Albania  2008            5.910    9912.19700                 7.270279
# 19      Albania  2009            5.885   10330.85800                 4.223695

# %%
# Remove all rows where Year is 2006
merged_df = merged_df[merged_df['Year'] != 2006]
merged_df.head()
# Out:
#         Entity  Year  democracy_score  gdpPerCapita  gdpPerCapita_pct_change
# 1  Afghanistan  2007             3.04    1461.91885                 6.944120
# 2  Afghanistan  2008             3.02    1556.84450                 6.493223
# 3  Afghanistan  2009             2.75    1791.50415                15.072774
# 4  Afghanistan  2010             2.48    2026.16380                13.098471
# 5  Afghanistan  2011             2.48    1961.09630                -3.211364

# %% [markdown]
# I have used the following link as a reference to categorize countries based on their democracy indices.
# https://en.wikipedia.org/wiki/The_Economist_Democracy_Index

# %%
def categorize_democracy(score):
  if 8.00 <= score <= 10.00:
    return 'full'
  elif 6.00 <= score <= 7.99:
    return 'flawed'
  elif 4.00 <= score <= 5.99:
    return 'hybrid'
  elif 0.00 <= score <= 3.99:
    return 'authoritarian'
  else:
    return 'unknown'

# Apply the function to create a new column 'democracy_type'
merged_df['democracy_type'] = merged_df['democracy_score'].apply(categorize_democracy)

# Display the first few rows to verify the changes
merged_df.head()
# Out:
#         Entity  Year  democracy_score  gdpPerCapita  gdpPerCapita_pct_change  \
# 1  Afghanistan  2007             3.04    1461.91885                 6.944120
# 2  Afghanistan  2008             3.02    1556.84450                 6.493223
# 3  Afghanistan  2009             2.75    1791.50415                15.072774
# 4  Afghanistan  2010             2.48    2026.16380                13.098471
# 5  Afghanistan  2011             2.48    1961.09630                -3.211364
#
#   democracy_type
# 1  authoritarian
# 2  authoritarian
# 3  authoritarian
# 4  authoritarian
# 5  authoritarian

# %%
# Create dummy variables for 'democracy_type' with 'authoritarian' as the baseline
democracy_type_dummies = pd.get_dummies(merged_df['democracy_type'], prefix='democracy_type', drop_first=True)
# Concatenate the dummy variables with the original dataframe
merged_df = pd.concat([merged_df, democracy_type_dummies], axis=1)
merged_df.head()
# Out:
#         Entity  Year  democracy_score  gdpPerCapita  gdpPerCapita_pct_change  \
# 1  Afghanistan  2007             3.04    1461.91885                 6.944120
# 2  Afghanistan  2008             3.02    1556.84450                 6.493223
# 3  Afghanistan  2009             2.75    1791.50415                15.072774
# 4  Afghanistan  2010             2.48    2026.16380                13.098471
# 5  Afghanistan  2011             2.48    1961.09630                -3.211364
#
#   democracy_type  democracy_type_flawed  democracy_type_full  \
# 1  authoritarian                  False                False
# 2  authoritarian                  False                False
# 3  authoritarian                  False                False
# 4  authoritarian                  False                False
# 5  authoritarian                  False                False
#
#    democracy_type_hybrid
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# 5                  False

# %%
print(merged_df['gdpPerCapita_pct_change'].dtype)
print(merged_df[['democracy_type_flawed', 'democracy_type_full', 'democracy_type_hybrid']].dtypes)
# Out:
# float64
# democracy_type_flawed    bool
# democracy_type_full      bool
# democracy_type_hybrid    bool
# dtype: object

# %% [markdown]
# **Regression Analysis**

# %%
# Define the independent variables (X) and dependent variable (y)
X = merged_df[['democracy_type_flawed', 'democracy_type_full', 'democracy_type_hybrid']].astype(int)
y = merged_df['gdpPerCapita_pct_change']
# Add a constant to the independent variables
X = sm.add_constant(X)
# Fit the regression model
model = sm.OLS(y, X).fit()
# Print the summary of the regression model
print(model.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gdpPerCapita_pct_change   R-squared:                       0.010
# Model:                                 OLS   Adj. R-squared:                  0.008
# Method:                      Least Squares   F-statistic:                     8.243
# Date:                     Fri, 25 Oct 2024   Prob (F-statistic):           1.86e-05
# Time:                             14:30:54   Log-Likelihood:                -7828.3
# No. Observations:                     2567   AIC:                         1.566e+04
# Df Residuals:                         2563   BIC:                         1.569e+04
# Df Model:                                3
# Covariance Type:                 nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.3823      0.185      7.460      0.000       1.019       1.746
# democracy_type_flawed     0.8622      0.256      3.369      0.001       0.360       1.364
# democracy_type_full      -0.1730      0.322     -0.537      0.592      -0.805       0.459
# democracy_type_hybrid     1.0448      0.280      3.732      0.000       0.496       1.594
# ==============================================================================
# Omnibus:                     1869.500   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           413995.079
# Skew:                           2.433   Prob(JB):                         0.00
# Kurtosis:                      65.024   Cond. No.                         4.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# I tried to check the regression just by using a specific year for all the countries.

# %%
def run_regression_for_year(year):
  df_year = merged_df[merged_df['Year'] == year]
  X_year = df_year[['democracy_type_flawed', 'democracy_type_full', 'democracy_type_hybrid']].astype(int)
  X_year = sm.add_constant(X_year)
  y_year = df_year['gdpPerCapita_pct_change']
  model_year = sm.OLS(y_year, X_year).fit()
  return model_year.summary()

print(run_regression_for_year(2007))
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gdpPerCapita_pct_change   R-squared:                       0.064
# Model:                                 OLS   Adj. R-squared:                  0.046
# Method:                      Least Squares   F-statistic:                     3.548
# Date:                     Fri, 25 Oct 2024   Prob (F-statistic):             0.0160
# Time:                             14:31:09   Log-Likelihood:                -434.89
# No. Observations:                      160   AIC:                             877.8
# Df Residuals:                          156   BIC:                             890.1
# Df Model:                                3
# Covariance Type:                 nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     3.2266      0.536      6.021      0.000       2.168       4.285
# democracy_type_flawed     1.2810      0.747      1.716      0.088      -0.194       2.756
# democracy_type_full      -1.4409      0.893     -1.613      0.109      -3.205       0.323
# democracy_type_hybrid     0.8936      0.832      1.074      0.285      -0.750       2.537
# ==============================================================================
# Omnibus:                       19.812   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.949
# Skew:                          -0.140   Prob(JB):                     2.17e-19
# Kurtosis:                       6.580   Cond. No.                         4.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Regression with control variables**

# %% [markdown]
# I decided to take the inflation rate as a control variable.

# %%
inflation_data = pd.read_csv('Data/inflation.csv', header=2)  
inflation_data.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name  Indicator Code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 2  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  ...      2015       2016       2017       2018  \
# 0   NaN   NaN   NaN  ...  0.474764  -0.931196  -1.028282   3.626041
# 1   NaN   NaN   NaN  ...  5.245878   6.571396   6.399343   4.720805
# 2   NaN   NaN   NaN  ... -0.661709   4.383892   4.975952   0.626149
# 3   NaN   NaN   NaN  ...  2.130817   1.487416   1.725486   1.784050
# 4   NaN   NaN   NaN  ...  9.355972  30.694415  29.844480  19.628938
#
#         2019       2020       2021       2022       2023  Unnamed: 68
# 0   4.257462        NaN        NaN        NaN        NaN          NaN
# 1   4.653665   5.405162   7.240978  10.773751   7.126975          NaN
# 2   2.302373        NaN        NaN        NaN        NaN          NaN
# 3   1.760112   2.437609   3.653533   7.967574   4.670084          NaN
# 4  17.080954  22.271539  25.754295  21.355290  13.644102          NaN
#
# [5 rows x 69 columns]

# %%
inflation_data = inflation_data.drop(columns=['Unnamed: 68'])
inflation_long = inflation_data.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
                   var_name='Year', 
                   value_name='Inflation')
inflation_long['Year'] = inflation_long['Year'].astype(int)
inflation_long = inflation_long.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'])
inflation_long.rename(columns={'Country Name': 'Entity'}, inplace=True)
inflation_long.head()
# Out:
#                         Entity  Year  Inflation
# 0                        Aruba  1960        NaN
# 1  Africa Eastern and Southern  1960        NaN
# 2                  Afghanistan  1960        NaN
# 3   Africa Western and Central  1960        NaN
# 4                       Angola  1960        NaN

# %%
filtered_inflation_long = inflation_long[inflation_long['Entity'].isin(merged_df['Entity'].unique())]
filtered_inflation_long = filtered_inflation_long[filtered_inflation_long['Year'].isin(merged_df['Year'].unique())]
filtered_inflation_long.head()
# Out:
#                      Entity  Year  Inflation
# 12504           Afghanistan  2007   8.680571
# 12506                Angola  2007  12.251497
# 12507               Albania  2007   2.932682
# 12510  United Arab Emirates  2007        NaN
# 12511             Argentina  2007        NaN

# %%
# Get the list of unique entities in the merged_df
entities_in_merged_df = set(merged_df['Entity'])
# Get the list of unique entities in the filtered_inflation_long
entities_in_inflation = set(filtered_inflation_long['Entity'])
# Find the entities that are in merged_df but not in filtered_inflation_long
entities_without_inflation_data = entities_in_merged_df - entities_in_inflation
print(f"Number of countries without inflation data: {len(entities_without_inflation_data)}")
print(f"Countries without inflation data: {entities_without_inflation_data}")
# Out:
# Number of countries without inflation data: 16
# Countries without inflation data: {'East Timor', 'Congo', 'Cape Verde', 'Iran', 'South Korea', 'Kyrgyzstan', 'Gambia', 'Palestine', 'Turkey', 'Hong Kong', 'Egypt', 'Vietnam', 'Russia', 'Democratic Republic of Congo', 'Laos', 'Slovakia'}

# %%
# Drop the countries without inflation data from filtered_inflation_long
filtered_inflation_long = filtered_inflation_long[~filtered_inflation_long['Entity'].isin(entities_without_inflation_data)]
# Create a new dataframe from merged_df by removing the countries without inflation data
merged_df_filtered = merged_df[~merged_df['Entity'].isin(entities_without_inflation_data)]
# Join the dataframes on Entity and Year
final_df = pd.merge(merged_df_filtered, filtered_inflation_long, on=['Entity', 'Year'], how='inner')
final_df.head()
# Out:
#         Entity  Year  democracy_score  gdpPerCapita  gdpPerCapita_pct_change  \
# 0  Afghanistan  2007             3.04    1461.91885                 6.944120
# 1  Afghanistan  2008             3.02    1556.84450                 6.493223
# 2  Afghanistan  2009             2.75    1791.50415                15.072774
# 3  Afghanistan  2010             2.48    2026.16380                13.098471
# 4  Afghanistan  2011             2.48    1961.09630                -3.211364
#
#   democracy_type  democracy_type_flawed  democracy_type_full  \
# 0  authoritarian                  False                False
# 1  authoritarian                  False                False
# 2  authoritarian                  False                False
# 3  authoritarian                  False                False
# 4  authoritarian                  False                False
#
#    democracy_type_hybrid  Inflation
# 0                  False   8.680571
# 1                  False  26.418664
# 2                  False  -6.811161
# 3                  False   2.178538
# 4                  False  11.804186

# %%
# Remove rows where Inflation is NaN
final_df = final_df.dropna(subset=['Inflation'])
final_df.head()
# Out:
#         Entity  Year  democracy_score  gdpPerCapita  gdpPerCapita_pct_change  \
# 0  Afghanistan  2007             3.04    1461.91885                 6.944120
# 1  Afghanistan  2008             3.02    1556.84450                 6.493223
# 2  Afghanistan  2009             2.75    1791.50415                15.072774
# 3  Afghanistan  2010             2.48    2026.16380                13.098471
# 4  Afghanistan  2011             2.48    1961.09630                -3.211364
#
#   democracy_type  democracy_type_flawed  democracy_type_full  \
# 0  authoritarian                  False                False
# 1  authoritarian                  False                False
# 2  authoritarian                  False                False
# 3  authoritarian                  False                False
# 4  authoritarian                  False                False
#
#    democracy_type_hybrid  Inflation
# 0                  False   8.680571
# 1                  False  26.418664
# 2                  False  -6.811161
# 3                  False   2.178538
# 4                  False  11.804186

# %%
# Define the independent variables (X) and dependent variable (y)
X = final_df[['democracy_type_flawed', 'democracy_type_full', 'democracy_type_hybrid','Inflation']].astype(int)
y = final_df['gdpPerCapita_pct_change']
# Add a constant to the independent variables
X = sm.add_constant(X)
# Fit the regression model
model = sm.OLS(y, X).fit()
# Print the summary of the regression model
print(model.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gdpPerCapita_pct_change   R-squared:                       0.016
# Model:                                 OLS   Adj. R-squared:                  0.014
# Method:                      Least Squares   F-statistic:                     8.817
# Date:                     Fri, 25 Oct 2024   Prob (F-statistic):           4.63e-07
# Time:                             14:30:54   Log-Likelihood:                -6789.8
# No. Observations:                     2230   AIC:                         1.359e+04
# Df Residuals:                         2225   BIC:                         1.362e+04
# Df Model:                                4
# Covariance Type:                 nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.4123      0.216      6.533      0.000       0.988       1.836
# democracy_type_flawed     0.9064      0.280      3.235      0.001       0.357       1.456
# democracy_type_full      -0.2111      0.342     -0.617      0.537      -0.882       0.460
# democracy_type_hybrid     1.0967      0.307      3.570      0.000       0.494       1.699
# Inflation                -0.0198      0.006     -3.139      0.002      -0.032      -0.007
# ==============================================================================
# Omnibus:                     1840.382   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           481545.185
# Skew:                           2.969   Prob(JB):                         0.00
# Kurtosis:                      74.745   Cond. No.                         79.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def run_regression_for_year_with_inflation(year): # please ignore the repetition in code 
  df_year = final_df[final_df['Year'] == year]
  X_year = df_year[['democracy_type_flawed', 'democracy_type_full', 'democracy_type_hybrid', 'Inflation']].astype(float)
  y_year = df_year['gdpPerCapita_pct_change']
  X_year = sm.add_constant(X_year)
  model_year = sm.OLS(y_year, X_year).fit()
  return model_year.summary()
print(run_regression_for_year_with_inflation(2007))
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gdpPerCapita_pct_change   R-squared:                       0.170
# Model:                                 OLS   Adj. R-squared:                  0.145
# Method:                      Least Squares   F-statistic:                     6.826
# Date:                     Fri, 25 Oct 2024   Prob (F-statistic):           4.99e-05
# Time:                             14:30:54   Log-Likelihood:                -348.16
# No. Observations:                      138   AIC:                             706.3
# Df Residuals:                          133   BIC:                             720.9
# Df Model:                                4
# Covariance Type:                 nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     2.2249      0.620      3.590      0.000       0.999       3.451
# democracy_type_flawed     0.6989      0.675      1.035      0.302      -0.636       2.034
# democracy_type_full      -1.0816      0.800     -1.352      0.179      -2.665       0.501
# democracy_type_hybrid     0.3230      0.773      0.418      0.677      -1.207       1.852
# Inflation                 0.2163      0.055      3.962      0.000       0.108       0.324
# ==============================================================================
# Omnibus:                       22.653   Durbin-Watson:                   2.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.103
# Skew:                           0.872   Prob(JB):                     1.07e-07
# Kurtosis:                       4.595   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Results**

# %% [markdown]
# 1. **I decided to take the GDP per capita percentage change as the metric for economic growth and categorized the countries among four groups based on their democracy indices. I was expecting a higher R^2, but I only got a R^2 score of 0.010 when I included all the countries and the data from all years.**
#
# 2. **When I included a control variable i.e. inflation rate in my regression model, the R^2 score had a neligible improvement to 0.0160.**
#
# 3. **I did the analysis also for a specific year, such as 2007, both with and without control variables. Without control variables, the R^2 was 0.060, and it improved to 0.170 after I used the control variable.**

# %% [markdown]
# **Conclusion and limitations**

# %% [markdown]
# In conclusion, the analysis did not establish that democracy drives economic growth, as causation remains far off, especially given that even correlation was weak. The low R² value suggests that democracy and economic growth may not be strongly linked. However, after introducing a control variable, we observed a slight improvement in correlation, indicating that if we account for additional factors—such as literacy rates, geographic indicators, or other economic influencers that are not collinear with democracy type—more meaningful insights may emerge. Expanding the model with these variables could offer a clearer understanding of the relationship between governance and economic outcomes.
